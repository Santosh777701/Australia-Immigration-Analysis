# %%
import pandas as pd

# %%
file_path="C:/SQL/Australia_data.csv"

# %%
df = pd.read_csv(file_path)

# %%
#checking first 10 rows 
df.head(10)
# Out:
#                 OdName CODE                         AreaName          RegName  \
# 0          Afghanistan  AFG                             Asia    Southern Asia
# 1              Albania  ALB                           Europe  Southern Europe
# 2              Algeria  DZA                           Africa  Northern Africa
# 3       American Samoa  ASM                          Oceania        Polynesia
# 4              Andorra  AND                           Europe  Southern Europe
# 5               Angola  AGO                           Africa    Middle Africa
# 6             Anguilla  AIA  Latin America and the Caribbean        Caribbean
# 7  Antigua and Barbuda  ATG  Latin America and the Caribbean        Caribbean
# 8            Argentina  ARG  Latin America and the Caribbean    South America
# 9              Armenia  ARM                             Asia     Western Asia
#
#               DevName  1980  1981  1982  1983  1984  ...  1999  2000  2001  \
# ...

# %%
df.columns = df.columns.str.strip()  # Clean column names
print("Data Loaded Successfully!")
df.head(10)
# Out:
# Data Loaded Successfully!
#                 OdName CODE                         AreaName          RegName  \
# 0          Afghanistan  AFG                             Asia    Southern Asia
# 1              Albania  ALB                           Europe  Southern Europe
# 2              Algeria  DZA                           Africa  Northern Africa
# 3       American Samoa  ASM                          Oceania        Polynesia
# 4              Andorra  AND                           Europe  Southern Europe
# 5               Angola  AGO                           Africa    Middle Africa
# 6             Anguilla  AIA  Latin America and the Caribbean        Caribbean
# 7  Antigua and Barbuda  ATG  Latin America and the Caribbean        Caribbean
# 8            Argentina  ARG  Latin America and the Caribbean    South America
# 9              Armenia  ARM                             Asia     Western Asia
#
#               DevName  1980  1981  1982  1983  1984  ...  1999  2000  2001  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
total_immigration_2008 = df['2008'].sum()
print("Total Immigration in 2008:", total_immigration_2008)
# Out:
# Total Immigration in 2008: 531000

# %%
top_countries = df[['OdName', '2008']].sort_values(by='2008', ascending=False).head(5)
print("Top 5 Countries with Highest Immigration in 2008:")
print(top_countries)
# Out:
# Top 5 Countries with Highest Immigration in 2008:
#                                                 OdName   2008
# 208  United Kingdom of Great Britain and Northern I...  65160
# 95                                               India  58400
# 41                                               China  54300
# 143                                        New Zealand  46960
# 210                           United States of America  20860

# %%
# Plotting the graph on the  Immigration Trends Over Years
plt.figure(figsize=(12,6))
df.set_index('OdName')[['1980', '1990', '2000', '2008']].head(10).plot(kind='bar', figsize=(12,6))
plt.title("Immigration Trends Over Years")
plt.ylabel("Number of Immigrants    ")
plt.xlabel("Country")
plt.legend(title="Years")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='OdName', y='2008', data=top_countries, palette="viridis")
plt.title("Top 5 Countries with Highest Immigration in 2008")
plt.xlabel("Country")
plt.ylabel("Number of Immigrants")
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()
# Out:
# C:\Users\test\AppData\Local\Temp\ipykernel_16684\2606014744.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='OdName', y='2008', data=top_countries, palette="viridis")

# %%
# 3. Distribution of Immigration in 2008
plt.figure(figsize=(10,5))
sns.histplot(df['2008'], bins=30, kde=True, color='blue')
plt.title("Distribution of Immigration Numbers in 2008")
plt.xlabel("Number of Immigrants")
plt.ylabel("Frequency")
plt.show()

# %%
#corelation heat map
plt.figure(figsize=(12,8))
sns.heatmap(df.iloc[:, 5:].corr(), annot=True, cmap="coolwarm", fmt='.2f', annot_kws={"size": 8}, linewidths=0.5, linecolor='black')
plt.title("Correlation Heatmap of Immigration Data")
plt.show()

# %%
output_file = "Australia_data_processed.csv"
df.to_csv(output_file, index=False)
print(f"Processed data saved to {output_file}")

print("✅ Jupyter Notebook Data Analysis Completed Successfully!")
# Out:
# Processed data saved to Australia_data_processed.csv
# ✅ Jupyter Notebook Data Analysis Completed Successfully!
